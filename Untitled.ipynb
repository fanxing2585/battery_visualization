# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data from the CSV file
data = pd.read_csv("storage_registrations.csv")

# Figure 1: Histogram of Power_in_kW
plt.figure(figsize=(8, 6))
sns.histplot(data['Power_in_kW'], bins=20, kde=True)
plt.title("Distribution of Power_in_kW")
plt.xlabel("Power_in_kW")
plt.ylabel("Frequency")
plt.show()

# %%
# Figure 2: Scatter plot of Power_in_kW vs. Energy_in_kWh
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Power_in_kW', y='Energy_in_kWh', data=data)
plt.title("Scatter Plot of Power_in_kW vs. Energy_in_kWh")
plt.xlabel("Power_in_kW")
plt.ylabel("Energy_in_kWh")
plt.show()

# %%
# Figure 3: Boxplot of Power_in_kW by Battery_Technology
plt.figure(figsize=(10, 6))
sns.boxplot(x='Battery_Technology', y='Power_in_kW', data=data)
plt.title("Boxplot of Power_in_kW by Battery_Technology")
plt.xlabel("Battery_Technology")
plt.ylabel("Power_in_kW")
plt.xticks(rotation=45)
plt.show()

# %%
# Figure 4: Pairplot to explore relationships among numerical variables
sns.pairplot(data[['Power_in_kW', 'Energy_in_kWh']], diag_kind='kde')
plt.suptitle("Pairplot of Power_in_kW and Energy_in_kWh")
plt.show()

# %%
# Figure 5: Bar chart of the count of each Battery_Technology
plt.figure(figsize=(8, 6))
sns.countplot(x='Battery_Technology', data=data)
plt.title("Count of Each Battery_Technology")
plt.xlabel("Battery_Technology")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the CSV file
data = pd.read_csv("storage_registrations.csv")

# Calculate energy efficiency
data['Energy_Efficiency'] = data['Power_in_kW'] / data['Energy_in_kWh']

# Extract the installation years from the Installation_Date column
data['Installation_Year'] = pd.to_datetime(data['Installation_Date']).dt.year

# Group data by installation year and battery technology, calculate mean energy efficiency
grouped_data = data.groupby(['Installation_Year', 'Battery_Technology'])['Energy_Efficiency'].mean().reset_index()

# Create a bar chart with installation years on the x-axis, bars grouped by battery technology, and mean energy efficiency on the y-axis
plt.figure(figsize=(12, 6))

battery_technologies = data['Battery_Technology'].unique()
colors = sns.color_palette("husl", len(battery_technologies))

for i, battery_type in enumerate(battery_technologies):
    filtered_data = grouped_data[grouped_data['Battery_Technology'] == battery_type]
    installation_years = filtered_data['Installation_Year']
    mean_energy_efficiency = filtered_data['Energy_Efficiency']

    # Offset bars for different battery technologies
    offset = i * 0.2

    plt.bar(installation_years + offset, mean_energy_efficiency, width=4, color=colors[i], label=battery_type, alpha=0.7, align='center', edgecolor='black', linewidth=1)

plt.title("Mean Energy Efficiency by Installation Year and Battery Technology")
plt.xlabel("Installation Year")
plt.ylabel("Mean Energy Efficiency (Power / Energy)")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_46185/1079561801.py:12: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Installation_Year'] = pd.to_datetime(data['Installation_Date']).dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the CSV file
data = pd.read_csv("storage_registrations.csv")

# Calculate energy efficiency
data['Energy_Efficiency'] = data['Power_in_kW'] / data['Energy_in_kWh']

# Extract the installation years from the Installation_Date column
data['Installation_Year'] = pd.to_datetime(data['Installation_Date']).dt.year

# Filter the data for installation years later than 2000
filtered_data = data[data['Installation_Year'] > 2000]

# Group data by installation year and battery technology, calculate mean energy efficiency
grouped_data = filtered_data.groupby(['Installation_Year', 'Battery_Technology'])['Energy_Efficiency'].mean().reset_index()

# Create a bar chart with installation years on the x-axis, bars grouped by battery technology, and mean energy efficiency on the y-axis
plt.figure(figsize=(12, 6))

battery_technologies = filtered_data['Battery_Technology'].unique()
colors = sns.color_palette("husl", len(battery_technologies))

for i, battery_type in enumerate(battery_technologies):
    filtered_group = grouped_data[grouped_data['Battery_Technology'] == battery_type]
    installation_years = filtered_group['Installation_Year']
    mean_energy_efficiency = filtered_group['Energy_Efficiency']

    # Offset bars for different battery technologies
    offset = i * 0.2

    plt.bar(installation_years + offset, mean_energy_efficiency, width=0.2, color=colors[i], label=battery_type, alpha=0.7, align='center', edgecolor='black', linewidth=1)

plt.title("Mean Energy Efficiency by Installation Year and Battery Technology (Years > 2000)")
plt.xlabel("Installation Year")
plt.ylabel("Mean Energy Efficiency (Power / Energy)")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_46185/3214941367.py:12: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Installation_Year'] = pd.to_datetime(data['Installation_Date']).dt.year

# %%
grouped_data
# Out:
#      Installation_Year                           Battery_Technology  \
# 0                 2001                             Lithium-Batterie
# 1                 2001                                 kein Eintrag
# 2                 2002                             Lithium-Batterie
# 3                 2002                            Sonstige_Batterie
# 4                 2002                                 kein Eintrag
# ..                 ...                                          ...
# 97                2020                             Lithium-Batterie
# 98                2020  Nickel-Cadmium-/Nickel-Metallhybridbatterie
# 99                2020                          Redox-Flow-Batterie
# 100               2020                            Sonstige_Batterie
# 101               2020                                 kein Eintrag
#
#      Energy_Efficiency
# 0             0.677409
# 1            61.186667
# 2             0.730769
# 3             1.000000
# 4             0.616902
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the CSV file
data = pd.read_csv("storage_registrations.csv")

# Extract the installation years from the Installation_Date column
data['Installation_Year'] = pd.to_datetime(data['Installation_Date']).dt.year

# Filter the data for installation years later than 2000
filtered_data = data[data['Installation_Year'] > 2000]

# Group data by installation year and battery technology, count the number of installations
grouped_data = filtered_data.groupby(['Installation_Year', 'Battery_Technology'])['ID'].count().unstack(fill_value=0)

# Create a bar chart with installation years on the x-axis and the count of each battery technology on the y-axis
plt.figure(figsize=(12, 6))

battery_technologies = grouped_data.columns
colors = sns.color_palette("husl", len(battery_technologies))

for i, battery_type in enumerate(battery_technologies):
    trend_data = grouped_data[battery_type]
    
    # Offset bars for different battery technologies
    offset = i * 0.2

    plt.bar(trend_data.index + offset, trend_data, width=0.2, color=colors[i], label=battery_type, alpha=0.7, align='center', edgecolor='black', linewidth=1)

plt.title("Trend of Battery Technology Installations (Years > 2000)")
plt.xlabel("Installation Year")
plt.ylabel("Number of Installations")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_46185/1119714111.py:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Installation_Year'] = pd.to_datetime(data['Installation_Date']).dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the CSV file
data = pd.read_csv("storage_registrations.csv")

# Extract the installation years from the Installation_Date column
data['Installation_Year'] = pd.to_datetime(data['Installation_Date']).dt.year

# Filter the data for installation years after 2000
filtered_data = data[data['Installation_Year'] > 2000]

# Filter out rows with "Lithium" battery technology
filtered_data = filtered_data[filtered_data['Battery_Technology'] != "Lithium-Batterie"]

# Group data by installation year and battery technology, count the number of installations
grouped_data = filtered_data.groupby(['Installation_Year', 'Battery_Technology'])['ID'].count().unstack(fill_value=0)

# Create a bar chart with installation years on the x-axis and the count of each battery technology on the y-axis
plt.figure(figsize=(12, 6))

battery_technologies = grouped_data.columns
colors = sns.color_palette("husl", len(battery_technologies))

for i, battery_type in enumerate(battery_technologies):
    trend_data = grouped_data[battery_type]
    
    # Offset bars for different battery technologies
    offset = (i+2) * 0.2

    plt.bar(trend_data.index + offset, trend_data, width=0.2, color=colors[i], label=battery_type, alpha=0.7, align='center', edgecolor='black', linewidth=1)

plt.title("Trend of Battery Technology Installations (Years > 2000, Excluding Lithium)")
plt.xlabel("Installation Year")
plt.ylabel("Number of Installations")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_46185/356437691.py:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Installation_Year'] = pd.to_datetime(data['Installation_Date']).dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv("storage_registrations.csv")

# Calculate summary statistics
power_summary = data['Power_in_kW'].describe()
energy_summary = data['Energy_in_kWh'].describe()

# Create histograms
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
data['Power_in_kW'].plot.hist(bins=20, edgecolor='k')
plt.title("Power_in_kW Distribution")

plt.subplot(2, 2, 2)
data['Energy_in_kWh'].plot.hist(bins=20, edgecolor='k')
plt.title("Energy_in_kWh Distribution")

# Create box plots
plt.subplot(2, 2, 3)
data[['Power_in_kW', 'Energy_in_kWh']].plot.box()
plt.title("Box Plots")

# Create scatter plot
plt.subplot(2, 2, 4)
data.plot.scatter(x='Power_in_kW', y='Energy_in_kWh', alpha=0.5)
plt.title("Power vs. Energy")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_46185/4286575054.py:27: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 4)

# %%
pip dash_daq
# Out:
# ERROR: unknown command "dash_daq"
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
import seaborn as sns
import matplotlib.pyplot as plt
from io import BytesIO
import base64
# Out:
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_69907/942673189.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_69907/942673189.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
data = pd.read_csv("storage_registrations.csv")

# Data processing: Handle null values
data.dropna(subset=['Power_in_kW', 'Energy_in_kWh', 'Installation_Date', 'Battery_Technology'], inplace=True)

df = pd.DataFrame(data)

app = dash.Dash(__name__)


# Get the unique battery technology types from the dataset
available_battery_types = df['Battery_Technology'].unique()

# Create dropdown options from the unique battery types
dropdown_options = [{'label': tech_type, 'value': tech_type} for tech_type in available_battery_types]


# Define the layout of the dashboard
app.layout = html.Div([
    html.H1('Energy Installation Dashboard'),
    
    dcc.Graph(id='scatter-plot'),
    
    dcc.Dropdown(
        id='battery-selector',
        options=dropdown_options,
        value=available_battery_types,  # Set initial selected values (all available types)
        multi=True  # Allow multiple selections
    ),
    
    dcc.Graph(id='box-plot'),
    
    dcc.Graph(id='stacked-bar-chart'),
    
    dcc.Graph(id='battery-technology-pie'),
    
    html.Div(id='correlation-heatmap')
    
])

# %%
# Define callback for updating the scatter plot
@app.callback(
    Output('scatter-plot', 'figure'),
    [Input('battery-selector', 'value')]
)
def update_scatter_plot(selected_battery):
    if not isinstance(selected_battery, list):
        selected_battery = [selected_battery]
    filtered_df = df[df['Battery_Technology'].isin(selected_battery)]
    fig = px.scatter(filtered_df, x='Power_in_kW', y='Energy_in_kWh', color='Battery_Technology', title='Power vs. Energy')
    return fig

# Define callback for updating the box plot
@app.callback(
    Output('box-plot', 'figure'),
    [Input('battery-selector', 'value')]
)
def update_box_plot(selected_battery):
    if not isinstance(selected_battery, list):
        selected_battery = [selected_battery]

    filtered_df = df[df['Battery_Technology'].isin(selected_battery)]
    fig = go.Figure()

    for tech_type in selected_battery:
        filtered_tech_df = filtered_df[filtered_df['Battery_Technology'] == tech_type]
        fig.add_trace(go.Box(y=filtered_tech_df['Power_in_kW'], name=tech_type))

    fig.update_layout(title='Box Plot of Power Capacity', yaxis_title='Power_in_kW')
    return fig

# Define callback for updating the stacked bar chart
@app.callback(
    Output('stacked-bar-chart', 'figure'),
    [Input('battery-selector', 'value')]
)
def update_stacked_bar_chart(selected_battery):
    if not isinstance(selected_battery, list):
        selected_battery = [selected_battery]

    filtered_df = df[df['Battery_Technology'].isin(selected_battery)]
    filtered_df['Year'] = pd.to_datetime(filtered_df['Installation_Date']).dt.year  # Extract the year

    fig = go.Figure()

    for tech_type in selected_battery:
        filtered_tech_df = filtered_df[filtered_df['Battery_Technology'] == tech_type]
        tech_counts = filtered_tech_df['Year'].value_counts().sort_index()

        fig.add_trace(go.Bar(x=tech_counts.index, y=tech_counts, name=tech_type))

    fig.update_layout(title='Battery Technology Over Time', xaxis_title='Installation Year', yaxis_title='Count of Installations', barmode='stack')
    return fig

# Define callback for updating the battery technology pie chart
@app.callback(
    Output('battery-technology-pie', 'figure'),
    [Input('battery-selector', 'value')]
)
def update_battery_technology_pie(selected_battery):
    filtered_df = df[df['Battery_Technology'].isin(selected_battery)]

    pie_data = filtered_df['Battery_Technology'].value_counts()

    fig = go.Figure(data=[go.Pie(labels=pie_data.index, values=pie_data.values)])
    fig.update_layout(title='Battery Technology Distribution')
    return fig

# Define callback for updating the correlation heatmap
@app.callback(
    Output('correlation-heatmap', 'children'),
    [Input('battery-selector', 'value')]
)
def update_correlation_heatmap(selected_battery):
    filtered_df = df[df['Battery_Technology'].isin(selected_battery)]

    # Select the relevant columns for correlation
    relevant_columns = ['Power_in_kW', 'Energy_in_kWh', 'Installation_Date', 'Battery_Technology']
    numeric_columns = filtered_df[relevant_columns].select_dtypes(include=['number'])

    # Create a correlation matrix
    correlation_matrix = numeric_columns.corr()

    # Generate the correlation heatmap using seaborn
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title('Correlation Heatmap')

    # Save the heatmap to a temporary file
    plt.savefig('temp.png')
    plt.close()

    # Display the image in the dashboard
    with open('temp.png', 'rb') as img_file:
        encoded_image = base64.b64encode(img_file.read()).decode()

    return html.Img(src='data:image/png;base64,{}'.format(encoded_image))

                     
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_69907/2725851047.py:41: UserWarning:
#
# Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#
# /var/folders/ps/_kz7dl8n7q33lgpbf76cr7_m0000gn/T/ipykernel_69907/2725851047.py:41: UserWarning:
#
# Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.

# %%
# Out:
# ('01.01.1900',)
